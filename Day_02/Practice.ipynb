# %% [markdown]
# ## Variables & Commments

# %% [markdown]
# ### Variables

# %%
print('Python')
# Out:
# Python

# %%
name='codegnan'
print(name)
# Out:
# codegnan

# %%
Name='Python'
print(Name)
# Out:
# Python

# %%
Institute='Codegnan'
print(institute) # Error Because variable names mismatched both printing variable and declaring variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 Institute='Codegnan'
# ----> 2 print(institute)
#
# NameError: name 'institute' is not defined

# %%
Number1=1
print(Number1)
# Out:
# 1

# %%
7num=7
print(7num) # Variable should not start with numerical values
# Out:
#   Cell In[8], line 1
#     7num=7
#      ^
# SyntaxError: invalid syntax

# %%
)num=64
print()num) # Variable should not have special Symbols
# Out:
#   Cell In[9], line 1
#     )num=64
#     ^
# SyntaxError: unmatched ')'

# %%
my num=10
print(my num) # Variable should not contain space
# Out:
#   Cell In[10], line 1
#     my num=10
#        ^
# SyntaxError: invalid syntax

# %%
my_name='Dileep'
print(my_name)
# Out:
# Dileep

# %%
student='Dileep Kumar'
roll_number=4
print(student,roll_number)
# Out:
# Dileep Kumar 4

# %% [markdown]
# ### Comments

# %%
#Single Line Comment
#institute='Codegnan'
roll_number=4
print(institute,roll_number) # institute variable is arranged in comment and printing its variables leads to error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 #Single Line Comment
#       2 #institute='Codegnan'
#       3 roll_number=4
# ----> 4 print(institute,roll_number)
#
# NameError: name 'institute' is not defined

# %%
# #Multi Line Comment
# #institute='Codegnan'
# roll_number=4
# print(institute,roll_number)

# %%
'''Multi Line Comment
institute='Codegnan'
'''
"""roll_number=4
print(institute,roll_number)"""
# Out:
# 'roll_number=4\nprint(institute,roll_number)'

# %%
# Heading Making in jupyter using ### assign value, # Assig Values, ## Assign Values

# %% [markdown]
# ### assign value

# %% [markdown]
# # Assign Values

# %% [markdown]
# ## Assign Values

# %%
num1=1
student_name='Dileep'
percentage=8.71
print(num1)
print(student_name)
print(percentage)
print(name,student_name,percentage)
# Out:
# 1
# Dileep
# 8.71
# Python Dileep 8.71

# %% [markdown]
# ## Reassignment

# %%
cgpa=8.96
cgpa= 8.8
print(cgpa)
del cgpa
print(cgpa) # Error because cgpa variable deleted using del and printing again cgpa value
# Out:
# 8.8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       3 print(cgpa)
#       4 del cgpa
# ----> 5 print(cgpa)
#
# NameError: name 'cgpa' is not defined

# %% [markdown]
# ## Swapping Values

# %%
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
a=100
b=200
temp=a
a=b
b=temp
print(a,b)
# Out:
# 200 100
