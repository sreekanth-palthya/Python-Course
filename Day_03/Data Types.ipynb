# %% [markdown]
# ### Numeric Data Types

# %%
number=26
cgpa=8.9
c=2+8j
print(type(number),type(cgpa),type(c))
# Out:
# <class 'int'> <class 'float'> <class 'complex'>

# %%
c=5+6j
print(c)
# Out:
# (5+6j)

# %% [markdown]
# ### Sequence data type

# %%
#List
lst=list()
lst1=[]
lst2=[1,2,3,5]
lst3=[10,'jhfrew',67.88,'h']
print(type(lst1))
print(type(lst2))
lst3[1]=45
print(type(lst3))
print(lst2[3])
print(lst3)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# 5
# [10, 45, 67.88, 'h']

# %%
#Tuples
t=()
t1=tuple()
t2=(1,1,2,4,5)
print(tuple(t),tuple(t1),tuple(t2))
print(t2[3])
# Out:
# () () (1, 1, 2, 4, 5)
# 4

# %%
#Strings
string='jfakdsnj@#$%^&*'
s=''
s1=str()
print(type(string),type(s),type(s1))
print(s)
print(string[5])
string[5]=23
print(string) # Error because string is Immutale
# Out:
# <class 'str'> <class 'str'> <class 'str'>
#
# s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       6 print(s)
#       7 print(string[5])
# ----> 8 string[5]=23
#       9 print(string)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Mapping Data Type

# %%
#Sets & Dictionaries
set1={}
dictionary={}
set2=set()
set3={1,2,3,4,5,6,11,1,1,1,1}
d1=dict()
d2={}
print(d2)
print(d1)
d={'name':'Dileep','age':21,'Gender':'Male','CGPA':8.71,9:'i'}
for key,value in d.items():
    print(key,value)
print(d.keys())
print(d.items())
print(type(set1),type(dictionary),type(set2),type(set3),type(d1),type(d1))
print(set3)
# Out:
# {}
# {}
# name Dileep
# age 21
# Gender Male
# CGPA 8.71
# 9 i
# dict_keys(['name', 'age', 'Gender', 'CGPA', 9])
# dict_items([('name', 'Dileep'), ('age', 21), ('Gender', 'Male'), ('CGPA', 8.71), (9, 'i')])
# <class 'dict'> <class 'dict'> <class 'set'> <class 'set'> <class 'dict'> <class 'dict'>
# {1, 2, 3, 4, 5, 6, 11}

# %%
d2={'a':1,'b':1}
print(d2)
# Out:
# {'a': 1, 'b': 1}

# %%
d3={'a':1,'b':1,'a':4}
print(d3)
# Out:
# {'a': 4, 'b': 1}

# %%
#Type Casting

#Implicit Type Casting
print(True+6)
print(float(9))
print(4+9.4)
# Out:
# 7
# 9.0
# 13.4

# %%
#Explicit Type Casting
str1='lkvf'
l=list(str1)
print(l)
# Out:
# ['l', 'k', 'v', 'f']

# %% [markdown]
# ### Boolean Data Type

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(1))
# Out:
# True

# %% [markdown]
# ### None Data Type

# %%
a=None
print(type(a))
print(a)
# Out:
# <class 'NoneType'>
# None
