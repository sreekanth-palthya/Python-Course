# %% [markdown]
# ### Arithmetic Operator

# %%
a=200
b=100
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a/b)
print(a%b)
print(3**4)
# Out:
# 300
# 100
# 20000
# 2
# 2.0
# 0
# 81

# %%
a=int(input())
print(a)
# Out:
#  10
# 10

# %%
a,b=map(int,input().split())
print(a,b)
# Out:
#  10 20
# 10 20

# %%
a,b=map(str,input().split())
print(a,b)
# Out:
#  a b
# a b

# %% [markdown]
# ### Assignment Operator

# %%
a=200
a+=100
print(a)
# Out:
# 300

# %% [markdown]
# ### Comparision Operator

# %%
a=26
b=45
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ### Logical Operators

# %%
a=26
b=45
print(a>b and a<b)
print(a<=b and a!=b)
print(a==b and b>=a)
print()
print(a>b or a<b)
print(a<=b or a!=b)
print(a==b or b>=a)
print()
print(not a>b)
print(not a<b)
# Out:
# False
# True
# False
#
# True
# True
# True
#
# True
# False

# %% [markdown]
# ### Bitwise Operator

# %%
print(6 & 4)
print(6 | 4)
print(6^4)
print(4<<1)
print(8>>1)
print(8>>)
# Out:
# 4
# 6
# 2
# 8
# 4
# 0

# %% [markdown]
# ### Identity operator

# %%
l1=[10,20,30]
l2=[10,20,30]
l3=l1
print(l1 is l2)
print(l1 is l3)
print(l1==l3)
# Out:
# False
# True
# True

# %% [markdown]
# ### Membership Operator

# %%
l1=[10,20,30]
l2=[10,20,30]
l3=l1
print(l1 in l2)
print(l1 in l3)
print(l1==l3)
print(id(l1),id(l2),id(l3))
# Out:
# False
# False
# True
# 2548960309952 2548960591808 2548960309952

# %% [markdown]
# ### F-String formatting

# %%
a=int(input('Enter a number:'))
print(f'The entered value is {a}')
# Out:
# Enter a number: 10
# The entered value is 10

# %% [markdown]
# ### Problem

# %%
length=int(input('Enter Length:'))
breadth=int(input('Enter breadth:'))
Area=length*breadth
Perimeter=2*(length+breadth)
print(f'Area of rectangle: {Area} having length {length} & breadth {breadth}')
print(f'Perimeter of rectange is {Perimeter} having length {length} and breadth {breadth}')
# Out:
# Enter Length: 10
# Enter breadth: 20
# Area of rectangle: 200 having length 10 & breadth 20
# Perimeter of rectange is 60 having length 10 and breadth 20
