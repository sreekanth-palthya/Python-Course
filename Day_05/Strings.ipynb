# %% [markdown]
# ### Strings

# %%
s1='python2345@##$'
s=input()
print(type(s),type(s1))
# Out:
#  23453456
# <class 'str'> <class 'str'>

# %% [markdown]
# ### Slicing

# %%
s='Python Programming'
print(s[3:10:])
print(s[3:10:2])
print(s[:5])
print(s[6:])
print(s[::-1])
# Out:
# hon Pro
# hnPo
# Pytho
#  Programming
# gnimmargorP nohtyP

# %% [markdown]
# ### String Operations

# %%
s1='codegnan'
s2='students'
print(s1+s2)
print(s1*4)
print(s2*3)
print(s1<s2)
# Out:
# codegnanstudents
# codegnancodegnancodegnancodegnan
# studentsstudentsstudents
# True

# %% [markdown]
# ### String Methods

# %%
s1='stuDENts are good'
print(s1.lower())
print(s1.upper())
print(s1.capitalize())
print(s1.title())
print(s1.swapcase())
# Out:
# students are good
# STUDENTS ARE GOOD
# Students are good
# Students Are Good
# STUdenTS ARE GOOD

# %%
s1='stuDENts are good'
print(s1.islower())
print(s1.isupper())
print(s1.isalnum())
print(s1.isalpha())
print(s1.isdigit())
print(s1.isspace())
print(' '.isspace())
# Out:
# False
# False
# False
# False
# False
# False
# True

# %%
s1='stuDENts are good'
print(list(s1))
print(s1.split('#'))
print(s1.split())
print(' '.join(s1.split()))
# Out:
# ['s', 't', 'u', 'D', 'E', 'N', 't', 's', ' ', 'a', 'r', 'e', ' ', 'g', 'o', 'o', 'd']
# ['stuDENts are good']
# ['stuDENts', 'are', 'good']
# stuDENts are good

# %%
s='i love python'
print(s.replace('python','DSA'))
print(s)
# Out:
# i love DSA
# i love python

# %% [markdown]
# ### Strips

# %%
s='          python   Programming             '
print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
# python   Programming
# python   Programming
#           python   Programming
