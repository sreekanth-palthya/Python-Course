# %% [markdown]
# ### Lists

# %%
lst=[]
lst1=[1,2,4,5,5]
lst3=list(map(int,input().split(',')))
print(lst3)
# Out:
#  1,2,3,4
# [1, 2, 3, 4]

# %% [markdown]
# ### List Operations

# %%
l1=[1,2,3]
l2=[4,5,6]
print(l1+l2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(l1*3)
print(l2*5)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6]

# %% [markdown]
# ### List Methods

# %%
l=[1,2,3,4,5,6,6,7]
print(l)
l.append(10)
print(l)
l.append([20,30])
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7]
# [1, 2, 3, 4, 5, 6, 6, 7, 10]
# [1, 2, 3, 4, 5, 6, 6, 7, 10, [20, 30]]

# %%
l.extend([40,50,60])
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7, 10, [20, 30], 40, 50, 60]

# %%
l.insert(2,[70,80])
print(l)
l.insert(0,0)
print(l)
# Out:
# [0, 1, [70, 80], 2, [70, 80], [70, 80], [70, 80], 3, 4, 5, 6, 6, 7, 10, [20, 30], 40, 50, 60]
# [0, 0, 1, [70, 80], 2, [70, 80], [70, 80], [70, 80], 3, 4, 5, 6, 6, 7, 10, [20, 30], 40, 50, 60]

# %%
print(l.pop())
# Out:
# 60

# %%
print(l)
# Out:
# [0, 0, 1, [70, 80], 2, [70, 80], [70, 80], [70, 80], 3, 4, 5, 6, 6, 7, 10, [20, 30], 40, 50]

# %%
print(l.pop(5))
print(l.pop(0))
print(l)
# Out:
# [70, 80]
# 0
# [0, 1, [70, 80], 2, [70, 80], [70, 80], 3, 4, 5, 6, 6, 7, 10, [20, 30], 40, 50]

# %%
l=[0, 1, [70, 80], 2, [70, 80], [70, 80], 3, 4, 5, 6, 6, 7, 10, [20, 30], 40, 50]
l.remove(6)
print(l)
# del l
# print(l)
# Out:
# [0, 1, [70, 80], 2, [70, 80], [70, 80], 3, 4, 5, 6, 7, 10, [20, 30], 40, 50]

# %%
l.clear()
print(l)
# Out:
# []

# %%
lst=[70,20,90,30,100,50]
print(len(lst))
print(min(lst))
print(max(lst))
print(sum(lst))
lst.sort()
print(lst)
print(sorted(lst))
lst.sort(reverse=True)
print(lst)
# Out:
# 6
# 20
# 100
# 360
# [20, 30, 50, 70, 90, 100]
# [20, 30, 50, 70, 90, 100]
# [100, 90, 70, 50, 30, 20]

# %%
r=lst.copy()
print(r)
# Out:
# [100, 90, 70, 50, 30, 20]

# %% [markdown]
# ### Tuple

# %%
t=()
t1=tuple()
t=(1,2,1,2,1,3,4,5)
print(t[5])
# t[5]=6
# print(t)
t=(1,2,3,[10,20,30])
print(len(t))
t[3][2]=300
print(t)
print(len(t))
# Out:
# 3
# 4
# (1, 2, 3, [10, 20, 300])
# 4

# %%
# By using Explicit then we can access the values in results as tuple
t=(1,2,3)
l=list(t)
print(t)
print(l)
l[0]=10
print(l)
t1=tuple(l)
print(t1)
# Out:
# (1, 2, 3)
# [1, 2, 3]
# [10, 2, 3]
# (10, 2, 3)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(3)
# Out:
# 2
