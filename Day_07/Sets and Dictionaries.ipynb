# %% [markdown]
# ### Sets

# %%
s = set()
s1 = {}
print(type(s), type(s1))
print(s,s1)
# Out:
# <class 'set'> <class 'dict'>
# set() {}

# %%
s.add(10)
print(s)
# Out:
# {10}

# %%
s.update([20,30,40])
print(s)
s1={1,2,3,4,5,6,12,6,3}
print(s)
# Out:
# {40, 10, 20, 30}
# {40, 10, 20, 30}

# %%
s1.remove(20)
print(s1) # Error because 20 variable is not present in s1 list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s1.remove(20)
#       2 print(s1)
#
# NameError: name 's1' is not defined

# %%
s.discard(30)

# %%
s.update([30,40,50,60,70,55])
print(s)
# Out:
# {100, 70, 40, 50, 55, 90, 60, 30}

# %%
print(s)
s.update([90,100])
print(s)
# Out:
# set()
# {90, 100}

# %%
print(s.pop())
# Out:
# 70

# %%
print(s.pop())
# Out:
# 40

# %%
s.clear()
print(s)
# Out:
# set()

# %%
s1={1,3,4,4,5,5,6,7,8,}
print(s1)
# Out:
# {1, 3, 4, 5, 6, 7, 8}

# %%
print(s1)
# Out:
# {1, 3, 4, 5, 6, 7, 8}

# %%
del s1
print(s1) # Error because deleted set using del
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 del s1
# ----> 2 print(s1)
#
# NameError: name 's1' is not defined

# %% [markdown]
# ### Set Operations

# %%
s1={10,20,30,40}
s2={45,55,10,5}
print(s1.union(s2))
print(s1 | s2)
# Out:
# {5, 40, 10, 45, 20, 55, 30}
# {5, 40, 10, 45, 20, 55, 30}

# %%
print(s1.intersection(s2))
print(s1 & s2)
# Out:
# {10}
# {10}

# %%
print(s1.difference(s2))
print(s1-s2)
# Out:
# {40, 20, 30}
# {40, 20, 30}

# %%
print(s2.difference(s1))
print(s2-s1)
# Out:
# {5, 45, 55}
# {5, 45, 55}

# %%
print(s1.symmetric_difference(s2))
print(s1^s2)
# Out:
# {5, 40, 45, 20, 55, 30}
# {5, 40, 45, 20, 55, 30}

# %%
#Frozen Set
s=frozenset([10,20,30])
print(s)
# Out:
# frozenset({10, 20, 30})

# %%
s1={12,2,4,6}
s2={4,6}
print(s1.issubset(s2))
print(s2.issubset(s1))
# Out:
# False
# True

# %%
print(s1.issuperset(s2))
print(s2.issuperset(s1))
# Out:
# True
# False

# %% [markdown]
# ### Dictionaries

# %%
d={}
d1=dict()
d2={'name':'Codegnan','branch':'hyderabad','batch':'PFS66','no_students':51}
print(type(d),type(d1),type(d2))
# Out:
# <class 'dict'> <class 'dict'> <class 'dict'>

# %%
print(d2['name'])
# Out:
# Codegnan

# %%
d2['branch']='Vijaywada'
print(d2)
# Out:
# {'name': 'Codegnan', 'branch': 'Vijaywada', 'batch': 'PFS66', 'no_students': 51}

# %%
d2['subject']='Python'
print(d2)
# Out:
# {'name': 'Codegnan', 'branch': 'Vijaywada', 'batch': 'PFS66', 'no_students': 51, 'subject': 'Python'}

# %%
print(d2[]])
# Out:
#   Cell In[55], line 1
#     print(d2[]])
#              ^
# SyntaxError: invalid syntax

# %%
print(d2[0]) # Error Because Dictionaries doesn't supports Indexing
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 print(d2[0])
#
# KeyError: 0

# %%
d2.update({'key':'value'})

# %%
print(d2)
# Out:
# {'name': 'Codegnan', 'branch': 'Vijaywada', 'batch': 'PFS66', 'no_students': 51, 'subject': 'Python', 'key': 'value'}

# %%
d2.pop('key')
# Out:
# 'value'

# %%
print(d2)
# Out:
# {'name': 'Codegnan', 'branch': 'Vijaywada', 'batch': 'PFS66', 'no_students': 51, 'subject': 'Python'}

# %%
d2.popitem()
# Out:
# ('subject', 'Python')

# %%
print(d2.keys())
# Out:
# dict_keys(['name', 'branch', 'batch', 'no_students'])

# %%
print(d2.values())
# Out:
# dict_values(['Codegnan', 'Vijaywada', 'PFS66', 51])

# %%
print(d2.items())
# Out:
# dict_items([('name', 'Codegnan'), ('branch', 'Vijaywada'), ('batch', 'PFS66'), ('no_students', 51)])

# %%
d={1:'a',[10]:'j'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 d={1:'a',[10]:'j'}
#
# TypeError: unhashable type: 'list'

# %%
l=[10,20]
print(hash(l)) # Mutable types doesnt generate Hashing values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 l=[10,20]
# ----> 2 print(hash(l)) # Mutable types doesnt generate Hashing values
#
# TypeError: unhashable type: 'list'

# %%
x={10,20,30}
print(hash(x)) # Set doesn't supports hashing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 x={10,20,30}
# ----> 2 print(hash(x))
#
# TypeError: unhashable type: 'set'

# %%
x=10
print(hash(x))
# Out:
# 10

# %% [markdown]
# ### Packing and Unpacking

# %%
#Packing
t= 1,2,3,4
print(t)
# Out:
# (1, 2, 3, 4)

# %%
#Unpacking
print(*t)
# Out:
# 1 2 3 4

# %%
l=[10,20,30,40] # Packing automatically gives only Tuple data type
print(l)
# Out:
# [10, 20, 30, 40]

# %%
print(*l)
# Out:
# 10 20 30 40

# %% [markdown]
# ### Negation

# %% [raw]
# print(~10)

# %%
print(~-1)
# Out:
# 0

# %%
print(~-2)
# Out:
# 1
