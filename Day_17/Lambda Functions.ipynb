# %%
square=lambda x: x*x
print(square(20))
# Out:
# 400

# %%
# Greater element
greater= lambda a,b: a if a>b else b
print(greater(70,28))
# Out:
# 70

# %%
# Filter()
numbers=[1,2,3,4,5,6]
res=filter(lambda x: str(x), numbers)
print(res)
# Out:
# <filter object at 0x000001FF823429A0>

# %%
numbers=[1,2,3,4,5,6]
res=filter(lambda x: str(x), numbers)
print(res)
print(list(res))
# Out:
# <filter object at 0x000001F5326D2460>
# [1, 2, 3, 4, 5, 6]

# %%
numbers=[1,2,3,4,5,6]
res=filter(lambda x: x%2==0, numbers)
print(res)
print(list(res))
# Out:
# <filter object at 0x000001F5326D2D90>
# [2, 4, 6]

# %%
# map()
numbers=map(int,input().split())
print(list(numbers))
# Out:
#  10 20 30 40
# [10, 20, 30, 40]

# %%
# reduce()
from functools import reduce
numbers=[1,2,3,4,5]
res=reduce(lambda a,b: a+b,numbers)
print(res)
# Out:
# 15
