# %% [markdown]
# ### 1. Math

# %% [markdown]
# import math
# print(math.sqrt(25))
# print(math.factorial(5))
# print(math.pi)
# print(math.floor(5.8))
# print(math.ceil(3.4))
# print(math.sin(90))
# print(math.cos(90))
# print(math.tan(45))
# print(math.pow(2,3))

# %% [markdown]
# ### 2.Random

# %%
import random
random.randint(1,6)
n=[10,20,40,30,60]
print(random.choice(n))
print(random.choices(n,k=3))
print(random.sample(n,k=2))
print(random.random())
print(random.randrange(1,6))
print(random.uniform(1,6))
random.shuffle(n)
print(n)
# Out:
# 20
# [60, 10, 60]
# [10, 60]
# 0.5983078354240886
# 3
# 3.6907182663341667
# [40, 10, 60, 30, 20]

# %% [markdown]
# ### 3. Sys

# %%
import sys
print(sys.version)
print(sys.platform)
print(sys.path)
print(sys.exit)
# Out:
# 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]
# win32
# ['C:\\Users\\Dileepkumar\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\Dileepkumar\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\Dileepkumar\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\Dileepkumar\\AppData\\Local\\Programs\\Python\\Python313', '', 'C:\\Users\\Dileepkumar\\AppData\\Roaming\\Python\\Python313\\site-packages', 'C:\\Users\\Dileepkumar\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages']
# <built-in function exit>

# %% [markdown]
# ### 4. platform

# %%
import platform
print(platform.system())
print(platform.release())
print(platform.processor())
print(platform.python_version())
# Out:
# Windows
# 11
# Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# 3.13.1

# %% [markdown]
# ### 5. Collections

# %%
from collections import Counter
name='codegnan'
r=Counter(name)
print(r)
# Out:
# Counter({'n': 2, 'c': 1, 'o': 1, 'd': 1, 'e': 1, 'g': 1, 'a': 1})

# %%
from collections import Counter
nums=[1,2,3,4,1,2,10,2,2]
n=Counter(nums)
print(n)
# Out:
# Counter({2: 4, 1: 2, 3: 1, 4: 1, 10: 1})

# %%
name=input()
d={}
for ch in name:
    if ch not in d:
        d[ch]=1
    else:
        d[ch]+=1
print(d)
# Out:
#  Dileep
# {'D': 1, 'i': 1, 'l': 1, 'e': 2, 'p': 1}

# %%
from collections import defaultdict
d=defaultdict(int)
d['apple']=1
print(d['name'])
print(d)
dic={'a':2,'b':5,'c':10}
# print(dic['x']) # error due to x element is not in dict
# Out:
# 0
# defaultdict(<class 'int'>, {'apple': 1, 'name': 0})

# %%
from collections import deque
d=deque([1,2,3])
print(d)
d.append(4)
print(d)
d.appendleft(10)
print(d)
d.pop()
print(d)
d.popleft()
print(d)
# Out:
# deque([1, 2, 3])
# deque([1, 2, 3, 4])
# deque([10, 1, 2, 3, 4])
# deque([10, 1, 2, 3])
# deque([1, 2, 3])

# %% [markdown]
# ### 6. Itertools

# %%
from itertools import permutations
numbers=[1,2,3,4]
print(list(permutations(numbers)))
# Out:
# [(1, 2, 3, 4), (1, 2, 4, 3), (1, 3, 2, 4), (1, 3, 4, 2), (1, 4, 2, 3), (1, 4, 3, 2), (2, 1, 3, 4), (2, 1, 4, 3), (2, 3, 1, 4), (2, 3, 4, 1), (2, 4, 1, 3), (2, 4, 3, 1), (3, 1, 2, 4), (3, 1, 4, 2), (3, 2, 1, 4), (3, 2, 4, 1), (3, 4, 1, 2), (3, 4, 2, 1), (4, 1, 2, 3), (4, 1, 3, 2), (4, 2, 1, 3), (4, 2, 3, 1), (4, 3, 1, 2), (4, 3, 2, 1)]

# %%
from itertools import combinations
print(list(combinations(numbers,2)))
# Out:
# [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]

# %%
from itertools import product
A=[1,2,4]
B=['A','B','C']
print(list(product(A,B)))
# Out:
# [(1, 'A'), (1, 'B'), (1, 'C'), (2, 'A'), (2, 'B'), (2, 'C'), (4, 'A'), (4, 'B'), (4, 'C')]

# %% [markdown]
# ### 7.Datetime

# %%
from datetime import datetime
now=datetime.now()
print(now)
print()
print(now.year)
print(now.month)
print(now.day)
print()
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 2026-09-12 00:24:15.466566
#
# 2026
# 9
# 12
#
# 0
# 24
# 15

# %%
from datetime import date
today=date.today()
print(today)
# Manula Creation of a date
d=date(2026,10,10)
print(d)
# Out:
# 2026-09-12
# 2026-10-10

# %%
from datetime import date,timedelta
today=date.today()
future=today+timedelta(days=30)
print(future)
past=today-timedelta(days=5)
print(past)
# Out:
# 2026-10-12
# 2026-09-07

# %%
from datetime import datetime
now=datetime.now()
print(now.strftime('%d-%m-%y'))
print(now.strftime('%d-%m-%Y'))
# Out:
# 12-09-26
# 12-09-2026
