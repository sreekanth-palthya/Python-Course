# %% [markdown]
# ### Exception Handling

# %%
a=10
b=10
print(a/b)
# Out:
# 1.0

# %% [markdown]
# #### Runtime Errors

# %%
a=10
b='d'
print(a/b) # Error due to Different data types using mathematical operations
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 a=10
#       2 b='d'
# ----> 3 print(a/b) # Error due to Different data types using mathematical operations
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
d={'c':4}
print(d['g']) # KeyError because element is absent in dictionary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 d={'c':4}
# ----> 2 print(d['g'])
#
# KeyError: 'g'

# %%
l=[1,2,3,4,5]
print(l[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 l=[1,2,3,4,5]
# ----> 2 print(l[10])
#
# IndexError: list index out of range

# %%
a=int(input())
b=int(input())
try:
    print(a/b)
except:
    print('Something went wrong')
else:
    print('there is no Error')
finally:
    print('Execution Done')
# Out:
#  10
#  3
# 3.3333333333333335
# there is no Error
# Execution Done

# %%
a=int(input())
b=int(input())
try:
    print(a/b)
except:
    print('Something went wrong')
else:
    print('there is no Error')
finally:
    print('Execution Done')
# Out:
#  10
#  0
# Something went wrong
# Execution Done

# %%
a=int(input())
b=int(input())
try:
    print(a/b)
except ZeroDivisionError as e:
    print(e)
else:
    print('there is no Error')
finally:
    print('Execution Done')
# Out:
#  10
#  0
# division by zero
# Execution Done

# %%
a=int(input())
b=input()
try:
    print(a/b)
except ZeroDivisionError as e:
    print(e)
except ValueError as v:
    print(v)
else:
    print('there is no Error')
finally:
    print('Execution Done')
# Out:
#  10
#  h
# Execution Done
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 12
#       8     print(v)
#       9 else:
#      10     print('there is no Error')
#      11 finally:
# ---> 12     print('Execution Done')
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
a=int(input())
b=input()
try:
    print(a/b)
except ZeroDivisionError as e:
    print(e)
except ValueError as v:
    print(v)
except TypeError as t:
    print(t)
else:
    print('there is no Error')
finally:
    print('Execution Done')
# Out:
#  10
#  jhbv
# unsupported operand type(s) for /: 'int' and 'str'
# Execution Done

# %%
a=int(input())
b=input()
try:
    print(a/b)
except ZeroDivisionError as e:
    print(e)
except ValueError as v:
    print(v)
except TypeError as t:
    print(t)
else:
    print('there is no Error')
finally:
    print('Execution Done')

print('Codegnan')
# Out:
#  1345
#  cxch
# unsupported operand type(s) for /: 'int' and 'str'
# Execution Done
# Codegnan

# %%
age=14
if age<18:
    raise AgeError('Age is less')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 age=14
#       2 if age<18:
# ----> 3     raise AgeError('Age is less')
#
# NameError: name 'AgeError' is not defined

# %%
age=14
try:
    if age<18:
        raise AgeError('Age is less')
except:
    print('code is not working')
# Out:
# code is not working

# %%
class AgeError(Exception):
    pass
try:
    if age<18:
        raise AgeError('Age is less')
except AgeError as a:
    print(a)
# Out:
# Age is less

# %% [markdown]
# ### File Handling

# %%
file=open('test.txt','w')
data='Hi'
file.write(data)
# Out:
# 2

# %%
data='Python'
file.write(data)
# Out:
# 6

# %%
file=open('test.txt','a')
file.write('Communication Skills')
# Out:
# 20

# %%
file=open('test.txt','r')
file.readline()
# Out:
# 'HiPythonCommunication Skills'

# %%
file=open('test.txt','r')
file.read()
# Out:
# 'HiPythonCommunication Skills'

# %%
file=open('test.txt','w')
data='Hi'
file.write(data)
file.close()

# %%
file=open('test.txt','w')
data='Hi'
file.write(data)
file.close()
with open('test.txt','w') as file1
# Out:
#   Cell In[35], line 5
#     with open('test.txt','w') as file1
#                                       ^
# SyntaxError: expected ':'
